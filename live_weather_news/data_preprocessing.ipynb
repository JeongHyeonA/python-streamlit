# %% [markdown]
# ## 지역별 특보

# %%
import numpy as np
import requests
import pprint
import json
import pandas as pd
import datetime
from datetime import datetime, timedelta
import datetime
url = 'http://apis.data.go.kr/1360000/WthrWrnInfoService/getWthrWrnList'
params ={'serviceKey' : 'I3k49MWVfMM1ikcVAQtW+aBQeMCQuFa3+ZqXWrCmB1NqsdllN466vryE/9Nt1OhZ3nx46rQ6oaw0nGhO/FJULg==', 'pageNo' : '1', 'numOfRows' : '10', 'dataType' : 'JSON'}

response = requests.get(url, params=params)
contents = response.text
json_ob = json.loads(contents)
body = json_ob['response']['body']['items']['item']
body = pd.json_normalize(body)
body
# Out:
#   stnId                                              title          tmFc  \
# 0   143     [특보] 제12-93호 : 2022.12.26.16:00 / 대설주의보 해제 (*)  202212261600
# 1   108    [특보] 제12-281호 : 2022.12.26.16:00 / 대설주의보 해제 (*)  202212261600
# 2   159     [특보] 제12-50호 : 2022.12.26.14:00 / 풍랑주의보 해제 (*)  202212261400
# 3   143  [특보] 제12-92호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연장...  202212261400
# 4   108  [특보] 제12-280호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연...  202212261400
# 5   105  [특보] 제12-64호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연장...  202212261400
# 6   143     [특보] 제12-91호 : 2022.12.26.11:30 / 대설주의보 발표 (*)  202212261130
# 7   108    [특보] 제12-279호 : 2022.12.26.11:30 / 대설주의보 발표 (*)  202212261130
# 8   156     [특보] 제12-94호 : 2022.12.26.10:00 / 한파주의보 해제 (*)  202212261000
# 9   146     [특보] 제12-56호 : 2022.12.26.10:00 / 한파주의보 해제 (*)  202212261000
#
#    tmSeq
# 0     93
# 1    281
# 2     50
# 3     92
# 4    280
# 5     64
# 6     91
# 7    279
# 8     94
# 9     56

# %%
local_code = pd.read_excel('C:/Users/user/Documents/python-streamlit/위기대응 실시간 특보 조회/data/지역코드.xlsx')
local_code = local_code.drop([0],axis = 0)
for i in local_code.index:
    local_code.loc[i,'#STN_ID,']=local_code.loc[i,'#STN_ID,'][:-1]
    local_code.loc[i,'STN_KO,']=local_code.loc[i,'STN_KO,'][:-1]
local_code.rename(columns={'#STN_ID,':'stnId','STN_KO,':'지역명'},inplace=True)
special_report_df = pd.merge(body,local_code)
special_report_df=special_report_df[['stnId', '지역명','title', 'tmFc', 'tmSeq']]
special_report_df['발표시각'] = np.NaN

# %%
special_report_df
# Out:
#   stnId 지역명                                              title          tmFc  \
# 0   143  대구     [특보] 제12-93호 : 2022.12.26.16:00 / 대설주의보 해제 (*)  202212261600
# 1   143  대구  [특보] 제12-92호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연장...  202212261400
# 2   143  대구     [특보] 제12-91호 : 2022.12.26.11:30 / 대설주의보 발표 (*)  202212261130
# 3   108  서울    [특보] 제12-281호 : 2022.12.26.16:00 / 대설주의보 해제 (*)  202212261600
# 4   108  서울  [특보] 제12-280호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연...  202212261400
# 5   108  서울    [특보] 제12-279호 : 2022.12.26.11:30 / 대설주의보 발표 (*)  202212261130
# 6   159  부산     [특보] 제12-50호 : 2022.12.26.14:00 / 풍랑주의보 해제 (*)  202212261400
# 7   105  강릉  [특보] 제12-64호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연장...  202212261400
# 8   156  광주     [특보] 제12-94호 : 2022.12.26.10:00 / 한파주의보 해제 (*)  202212261000
# 9   146  전주     [특보] 제12-56호 : 2022.12.26.10:00 / 한파주의보 해제 (*)  202212261000
#
#    tmSeq  발표시각
# 0     93   NaN
# 1     92   NaN
# 2     91   NaN
# 3    281   NaN
# 4    280   NaN
# 5    279   NaN
# 6     50   NaN
# 7     64   NaN
# 8     94   NaN
# 9     56   NaN

# %%
import datetime

def datetime_changer(x):    
    datetime_x = datetime.datetime.strptime(x, '%Y%m%d%H%M')
    datetime_x = datetime_x.strftime('%Y년 %m월 %d일 %H시 %M분')
    return datetime_x

special_report_df['tmFc'] = special_report_df['tmFc'].astype('str')
special_report_df['발표시각'] = special_report_df['tmFc'].apply(lambda x: datetime_changer(x))

# %%
special_report_df
# Out:
#   stnId 지역명                                              title          tmFc  \
# 0   143  대구     [특보] 제12-93호 : 2022.12.26.16:00 / 대설주의보 해제 (*)  202212261600
# 1   143  대구  [특보] 제12-92호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연장...  202212261400
# 2   143  대구     [특보] 제12-91호 : 2022.12.26.11:30 / 대설주의보 발표 (*)  202212261130
# 3   108  서울    [특보] 제12-281호 : 2022.12.26.16:00 / 대설주의보 해제 (*)  202212261600
# 4   108  서울  [특보] 제12-280호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연...  202212261400
# 5   108  서울    [특보] 제12-279호 : 2022.12.26.11:30 / 대설주의보 발표 (*)  202212261130
# 6   159  부산     [특보] 제12-50호 : 2022.12.26.14:00 / 풍랑주의보 해제 (*)  202212261400
# 7   105  강릉  [특보] 제12-64호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연장...  202212261400
# 8   156  광주     [특보] 제12-94호 : 2022.12.26.10:00 / 한파주의보 해제 (*)  202212261000
# 9   146  전주     [특보] 제12-56호 : 2022.12.26.10:00 / 한파주의보 해제 (*)  202212261000
#
#    tmSeq                   발표시각
# 0     93  2022년 12월 26일 16시 00분
# 1     92  2022년 12월 26일 14시 00분
# 2     91  2022년 12월 26일 11시 30분
# 3    281  2022년 12월 26일 16시 00분
# 4    280  2022년 12월 26일 14시 00분
# 5    279  2022년 12월 26일 11시 30분
# 6     50  2022년 12월 26일 14시 00분
# 7     64  2022년 12월 26일 14시 00분
# 8     94  2022년 12월 26일 10시 00분
# 9     56  2022년 12월 26일 10시 00분

# %%
special_report_df.drop(columns='tmFc', inplace=True)
special_report_df.columns = ['지점코드', '지역명', '제목', '발표번호','발표시각']
special_report_df
# Out:
#   지점코드 지역명                                                 제목  발표번호  \
# 0  143  대구     [특보] 제12-93호 : 2022.12.26.16:00 / 대설주의보 해제 (*)    93
# 1  143  대구  [특보] 제12-92호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연장...    92
# 2  143  대구     [특보] 제12-91호 : 2022.12.26.11:30 / 대설주의보 발표 (*)    91
# 3  108  서울    [특보] 제12-281호 : 2022.12.26.16:00 / 대설주의보 해제 (*)   281
# 4  108  서울  [특보] 제12-280호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연...   280
# 5  108  서울    [특보] 제12-279호 : 2022.12.26.11:30 / 대설주의보 발표 (*)   279
# 6  159  부산     [특보] 제12-50호 : 2022.12.26.14:00 / 풍랑주의보 해제 (*)    50
# 7  105  강릉  [특보] 제12-64호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연장...    64
# 8  156  광주     [특보] 제12-94호 : 2022.12.26.10:00 / 한파주의보 해제 (*)    94
# 9  146  전주     [특보] 제12-56호 : 2022.12.26.10:00 / 한파주의보 해제 (*)    56
#
#                     발표시각
# 0  2022년 12월 26일 16시 00분
# 1  2022년 12월 26일 14시 00분
# 2  2022년 12월 26일 11시 30분
# 3  2022년 12월 26일 16시 00분
# 4  2022년 12월 26일 14시 00분
# 5  2022년 12월 26일 11시 30분
# 6  2022년 12월 26일 14시 00분
# 7  2022년 12월 26일 14시 00분
# 8  2022년 12월 26일 10시 00분
# 9  2022년 12월 26일 10시 00분

# %%
special_report_df
# Out:
#   stnId 지역명                                              title          tmFc  \
# 0   143  대구     [특보] 제12-93호 : 2022.12.26.16:00 / 대설주의보 해제 (*)  202212261600
# 1   143  대구  [특보] 제12-92호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연장...  202212261400
# 2   143  대구     [특보] 제12-91호 : 2022.12.26.11:30 / 대설주의보 발표 (*)  202212261130
# 3   108  서울    [특보] 제12-281호 : 2022.12.26.16:00 / 대설주의보 해제 (*)  202212261600
# 4   108  서울  [특보] 제12-280호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연...  202212261400
# 5   108  서울    [특보] 제12-279호 : 2022.12.26.11:30 / 대설주의보 발표 (*)  202212261130
# 6   159  부산     [특보] 제12-50호 : 2022.12.26.14:00 / 풍랑주의보 해제 (*)  202212261400
# 7   105  강릉  [특보] 제12-64호 : 2022.12.26.14:00 / 풍랑주의보 해제예고연장...  202212261400
# 8   156  광주     [특보] 제12-94호 : 2022.12.26.10:00 / 한파주의보 해제 (*)  202212261000
# 9   146  전주     [특보] 제12-56호 : 2022.12.26.10:00 / 한파주의보 해제 (*)  202212261000
#
#    tmSeq                   발표시각
# 0     93  2022년 12월 26일 16시 00분
# 1     92  2022년 12월 26일 14시 00분
# 2     91  2022년 12월 26일 11시 30분
# 3    281  2022년 12월 26일 16시 00분
# 4    280  2022년 12월 26일 14시 00분
# 5    279  2022년 12월 26일 11시 30분
# 6     50  2022년 12월 26일 14시 00분
# 7     64  2022년 12월 26일 14시 00분
# 8     94  2022년 12월 26일 10시 00분
# 9     56  2022년 12월 26일 10시 00분

# %% [markdown]
# ## 특보구역코드

# %%
special_local_code = pd.read_excel('C://Users//user//Documents//python-streamlit//data//특보구역코드.xlsx')

for i in local_code.index:
    special_local_code.loc[i,'LAT,']=special_local_code.loc[i,'LAT,'][:-1]
    special_local_code.loc[i,'LON,']=special_local_code.loc[i,'LON,'][:-1]
    special_local_code.loc[i,'#STN_ID,'] = special_local_code.loc[i,'#STN_ID,'][:-1]
    special_local_code.loc[i,'WRN_KO,'] = special_local_code.loc[i,'WRN_KO,'][:-1]
    special_local_code.loc[i,'STN_KO,'] = special_local_code.loc[i,'STN_KO,'][:-1]
special_local_code = special_local_code.drop([0],axis = 0)
special_local_code['LAT,'] = special_local_code['LAT,'].astype('float')
special_local_code['LON,'] = special_local_code['LON,'].astype('float')


special_local_code = special_local_code[['LAT,', 'LON,', 'WRN_KO,', 'STN_KO,','#STN_ID,']]
special_local_code.rename(columns={'#STN_ID,' : '지점코드'},inplace=True)

# %%
special_local_code
# Out:
#           LAT,       LON, WRN_KO, STN_KO, 지점코드
# 1    38.250850  128.56473   속초시평지      속초   90
# 2    37.947380  127.75443     춘천시     북춘천   93
# 3    38.147870  127.30420     철원군      철원   95
# 4    37.239520  131.86983   울릉도독도      독도   96
# 5    37.901880  127.06070    동두천시     동두천   98
# ..         ...        ...     ...     ...  ...
# 670  35.090040  128.98393   부산광역시      사하  950
# 671  35.508690  126.90733     정읍시     내장산  951
# 672  34.998390  128.67977     거제시      장목  953
# 673  35.431030  129.36011   울산광역시      온산  954
# 674  33.352361  126.53300   제주도산간   한라산남벽  965
#
# [674 rows x 5 columns]

# %%
map_lat_lod = pd.merge(special_report_df,special_local_code)
map_lat_lod
# Out:
#   지점코드 지역명                                                 제목  발표번호  \
# 0  143  대구     [특보] 제12-77호 : 2022.12.23.10:00 / 건조주의보 발표 (*)    77
# 1  143  대구     [특보] 제12-76호 : 2022.12.23.06:00 / 대설주의보 해제 (*)    76
# 2  108  서울  [특보] 제12-246호 : 2022.12.23.10:00 / 풍랑주의보 변경·건조...   246
# 3  108  서울  [특보] 제12-245호 : 2022.12.23.06:00 / 대설주의보 해제·대설...   245
# 4  159  부산     [특보] 제12-40호 : 2022.12.23.06:00 / 대설주의보 해제 (*)    40
# 5  146  전주     [특보] 제12-47호 : 2022.12.23.06:00 / 대설주의보 변경 (*)    47
# 6  133  대전     [특보] 제12-54호 : 2022.12.23.06:00 / 대설주의보 해제 (*)    54
# 7  131  청주     [특보] 제12-36호 : 2022.12.23.06:00 / 대설주의보 해제 (*)    36
# 8  156  광주      [특보] 제12-78호 : 2022.12.23.05:00 / 대설경보 변경 (*)    78
#
#                  발표시각      LAT,       LON, WRN_KO, STN_KO,
# 0  2022년12월23일 10시00분  35.87797  128.65296   대구광역시      대구
# 1  2022년12월23일 06시00분  35.87797  128.65296   대구광역시      대구
# 2  2022년12월23일 10시00분  37.57142  126.96580   서울서북권      서울
# 3  2022년12월23일 06시00분  37.57142  126.96580   서울서북권      서울
# 4  2022년12월23일 06시00분  35.10468  129.03203   부산광역시      부산
# 5  2022년12월23일 06시00분  35.84092  127.11718     전주시      전주
# 6  2022년12월23일 06시00분  36.37198  127.37211   대전광역시      대전
# 7  2022년12월23일 06시00분  36.63924  127.44066     청주시      청주
# 8  2022년12월23일 05시00분  35.17294  126.89156   광주광역시      광주

# %% [markdown]
# ## 특보 출력해주기

# %%
special_report_df
# Out:
#   지점코드 지역명                                                 제목  발표번호  \
# 0  143  대구     [특보] 제12-77호 : 2022.12.23.10:00 / 건조주의보 발표 (*)    77
# 1  143  대구     [특보] 제12-76호 : 2022.12.23.06:00 / 대설주의보 해제 (*)    76
# 2  108  서울  [특보] 제12-246호 : 2022.12.23.10:00 / 풍랑주의보 변경·건조...   246
# 3  108  서울  [특보] 제12-245호 : 2022.12.23.06:00 / 대설주의보 해제·대설...   245
# 4  159  부산     [특보] 제12-40호 : 2022.12.23.06:00 / 대설주의보 해제 (*)    40
# 5  146  전주     [특보] 제12-47호 : 2022.12.23.06:00 / 대설주의보 변경 (*)    47
# 6  133  대전     [특보] 제12-54호 : 2022.12.23.06:00 / 대설주의보 해제 (*)    54
# 7  131  청주     [특보] 제12-36호 : 2022.12.23.06:00 / 대설주의보 해제 (*)    36
# 8  156  광주      [특보] 제12-78호 : 2022.12.23.05:00 / 대설경보 변경 (*)    78
#
#                  발표시각
# 0  2022년12월23일 10시00분
# 1  2022년12월23일 06시00분
# 2  2022년12월23일 10시00분
# 3  2022년12월23일 06시00분
# 4  2022년12월23일 06시00분
# 5  2022년12월23일 06시00분
# 6  2022년12월23일 06시00분
# 7  2022년12월23일 06시00분
# 8  2022년12월23일 05시00분

# %%
import numpy as np
import requests
import pprint
import json
import pandas as pd
import datetime
from datetime import datetime, timedelta
import datetime
import streamlit as st
import folium
from folium.plugins import MarkerCluster
from folium.plugins import MiniMap
from streamlit_folium import st_folium

m = folium.Map(
    location=[special_local_code['LAT,'].mean(), special_local_code['LON,'].mean()],
    zoom_start= 7, width = '70%', height = '50%'
    )
coords = map_lat_lod[['LAT,', 'LON,', 'WRN_KO,', 'STN_KO,']]
text = str(special_report_df['제목']).split('/')
for idx in coords.index:
        result = ''.join(text[idx].split(' ')[1:3])
        folium.Marker([coords.loc[idx, 'LAT,'], coords.loc[idx, 'LON,']], icon = folium.Icon(color="green"), tooltip = coords.loc[idx,'WRN_KO,'] + '<br>[특보] :' + str(result)  ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a1871f134a219c191a14889924f5e57 {
#                     position: relative;
#                     width: 70.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a1871f134a219c191a14889924f5e57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a1871f134a219c191a14889924f5e57 = L.map(
#                 &quot;map_3a1871f134a219c191a14889924f5e57&quot;,
#                 {
#                     center: [36.355492986617215, 127.35963255986647],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab2b33db371b515db37f5e254d7d6439 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3a1871f134a219c191a14889924f5e57);
#
#
#             var marker_e02633ac9aa2c647f28c187fa83266e6 = L.marker(
#                 [35.87797, 128.65296],
#                 {}
#             ).addTo(map_3a1871f134a219c191a14889924f5e57);
#
#
#             var icon_a33a15ad8dde977e8b875f95848ddfe1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e02633ac9aa2c647f28c187fa83266e6.setIcon(icon_a33a15ad8dde977e8b875f95848ddfe1);
#
#
#             marker_e02633ac9aa2c647f28c187fa83266e6.bindTooltip(
#                 `&lt;div&gt;
#                      대구광역시&lt;br&gt;[특보] :
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_483cb7de070071d0a52d688616918738 = L.marker(
#                 [35.87797, 128.65296],
#                 {}
#             ).addTo(map_3a1871f134a219c191a14889924f5e57);
#
#
#             var icon_50cdefc72dc833d8bf8982faadb00dd0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_483cb7de070071d0a52d688616918738.setIcon(icon_50cdefc72dc833d8bf8982faadb00dd0);
#
#
#             marker_483cb7de070071d0a52d688616918738.bindTooltip(
#                 `&lt;div&gt;
#                      대구광역시&lt;br&gt;[특보] :건조주의보발표
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b975ea7d9b2f761ee5d717d2f9874ec6 = L.marker(
#                 [37.57142, 126.9658],
#                 {}
#             ).addTo(map_3a1871f134a219c191a14889924f5e57);
#
#
#             var icon_ecc2e8a35376638ee352744bab121d68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b975ea7d9b2f761ee5d717d2f9874ec6.setIcon(icon_ecc2e8a35376638ee352744bab121d68);
#
#
#             marker_b975ea7d9b2f761ee5d717d2f9874ec6.bindTooltip(
#                 `&lt;div&gt;
#                      서울서북권&lt;br&gt;[특보] :대설주의보해제
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9a5769cd22037ea2a23ba63fa924a9ac = L.marker(
#                 [37.57142, 126.9658],
#                 {}
#             ).addTo(map_3a1871f134a219c191a14889924f5e57);
#
#
#             var icon_6efb4c168e119c972917258f92afaa6b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9a5769cd22037ea2a23ba63fa924a9ac.setIcon(icon_6efb4c168e119c972917258f92afaa6b);
#
#
#             marker_9a5769cd22037ea2a23ba63fa924a9ac.bindTooltip(
#                 `&lt;div&gt;
#                      서울서북권&lt;br&gt;[특보] :풍랑주의보변경·건조...
# 3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_84f5b6cf4883bc910477472836231c6e = L.marker(
#                 [35.10468, 129.03203],
#                 {}
#             ).addTo(map_3a1871f134a219c191a14889924f5e57);
#
#
#             var icon_2b27657422186e4d18f116e88fbffd8c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot
